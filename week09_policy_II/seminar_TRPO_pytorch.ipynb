# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash
    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'
# Out:
# Starting virtual X frame buffer: Xvfb../xvfb: line 24: start-stop-daemon: command not found
# .

# %% [markdown]
# ### Let's make a TRPO!
#
# In this notebook we will write the code of the one Trust Region Policy Optimization.
# As usually, it contains a few different parts which we are going to reproduce.

# %%
from typing import Tuple

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import gym

env = gym.make("Acrobot-v1")
env.reset()
observation_shape = env.observation_space.shape
n_actions = env.action_space.n

print("Observation Space", env.observation_space)
print("Action Space", env.action_space)
# Out:
# Observation Space Box([ -1.        -1.        -1.        -1.       -12.566371 -28.274334], [ 1.        1.        1.        1.       12.566371 28.274334], (6,), float32)
# Action Space Discrete(3)

# %% [markdown]
# !pipenv install pyglet==1.5.27

# %%
from PIL import Image

Image.fromarray(env.render('rgb_array'))
# Out:
# 2022-12-29 14:05:38.025 Python[65187:4747046] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/p3/4j53xc_50yv4yqz952bnybrm0000gn/T/org.python.python.savedState
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %% [markdown]
# ### Step 1: Defining a network
#
# With all it's complexity, at it's core TRPO is yet another policy gradient method.
#
# This essentially means we're actually training a stochastic policy $\pi_\theta \left( a \middle| s \right)$.
#
# And yes, it's gonna be a neural network. So let's start by defining one.

# %%
class TRPOAgent(nn.Module):
    def __init__(self, state_shape: Tuple[int], n_actions: int):
        '''
        Here you should define your model
        You should have LOG-PROBABILITIES as output because you will need it to compute loss
        We recommend that you start simple:
        use 1-2 hidden layers with 100-500 units and relu for the first try
        '''
        nn.Module.__init__(self)

        assert isinstance(state_shape, tuple)
        assert len(state_shape) == 1
        input_dim = state_shape[0]
        
        # Prepare your model here.
        self.dense_in = nn.Linear(input_dim, 250)
        self.dense_hid = nn.Linear(250, 300)
        self.dense_out = nn.Linear(300, n_actions)
        self.log_softmax = nn.LogSoftmax(1)
        self.relu = nn.ReLU()
        

    def forward(self, states: torch.Tensor):
        """
        takes agent's observation, returns log-probabilities
        :param state_t: a batch of states, shape = [batch_size, state_shape]
        """

        # Use your network to compute log_probs for the given states.
        model = nn.Sequential(
            self.dense_in, 
            self.relu,
            
            self.dense_hid, 
            self.relu,
            
            self.dense_out,
            self.log_softmax
        )
        log_probs = model(states)
#         counts = logits.exp()
#         probs = logits / logits.sum(-1, keepdims=True)
        
        return log_probs

    def get_log_probs(self, states: torch.Tensor):
        '''
        Log-probs for training
        '''
        return self.forward(states)

    def get_probs(self, states: torch.Tensor):
        '''
        Probs for interaction
        '''
        return torch.exp(self.forward(states))

    def act(self, obs: np.ndarray, sample: bool = True):
        '''
        Samples action from policy distribution (sample = True) or takes most likely action (sample = False)
        :param: obs - single observation vector
        :param sample: if True, samples from \pi, otherwise takes most likely action
        :returns: action (single integer) and probabilities for all actions
        '''

        with torch.no_grad():
            probs = self.get_probs(torch.tensor(obs[np.newaxis], dtype=torch.float32)).numpy()

        if sample:
            action = int(np.random.choice(n_actions, p=probs[0]))
        else:
            action = int(np.argmax(probs))

        return action, probs[0]


agent = TRPOAgent(observation_shape, n_actions)

# %%
# Check if log-probabilities satisfies all the requirements
log_probs = agent.get_log_probs(torch.tensor(env.reset()[np.newaxis], dtype=torch.float32))
assert (
    isinstance(log_probs, torch.Tensor) and
    log_probs.requires_grad
), "log_probs must be a torch.Tensor with grad"
assert log_probs.shape == (1, n_actions)
sums = torch.exp(log_probs).sum(dim=1)
assert torch.allclose(sums, torch.ones_like(sums))

# Demo use
print("sampled:", [agent.act(env.reset()) for _ in range(5)])
print("greedy:", [agent.act(env.reset(), sample=False) for _ in range(5)])
# Out:
# sampled: [(2, array([0.31789845, 0.33838865, 0.3437129 ], dtype=float32)), (0, array([0.3171794, 0.3392655, 0.3435551], dtype=float32)), (0, array([0.3175845 , 0.33649603, 0.34591934], dtype=float32)), (1, array([0.31586388, 0.33894926, 0.34518683], dtype=float32)), (0, array([0.3165693 , 0.33784872, 0.34558198], dtype=float32))]
# greedy: [(2, array([0.3169552 , 0.33808225, 0.34496254], dtype=float32)), (2, array([0.3167536 , 0.33923152, 0.34401488], dtype=float32)), (2, array([0.31683925, 0.33896363, 0.34419712], dtype=float32)), (2, array([0.31800383, 0.3358678 , 0.34612837], dtype=float32)), (2, array([0.31812754, 0.33673888, 0.34513354], dtype=float32))]

# %% [markdown]
# #### Flat parameters operations
#
# We are going to use it

# %%
def get_flat_params_from(model):
    params = [torch.ravel(param.detach()) for param in model.parameters()]
    flat_params = torch.cat(params)
    return flat_params


def set_flat_params_to(model, flat_params):
    prev_ind = 0
    for param in model.parameters():
        flat_size = int(np.prod(list(param.shape)))
        param.data.copy_(
            flat_params[prev_ind:prev_ind + flat_size].reshape(param.shape)
        )
        prev_ind += flat_size

# %% [markdown]
# Compute cumulative reward just like you did in vanilla REINFORCE

# %%
import scipy.signal


def get_cumulative_returns(r, gamma=1):
    """
    Computes cumulative discounted rewards given immediate rewards
    G_i = r_i + gamma*r_{i+1} + gamma^2*r_{i+2} + ...
    Also known as R(s,a).
    """
    r = np.array(r)
    assert r.ndim >= 1
    return scipy.signal.lfilter([1], [1, -gamma], r[::-1], axis=0)[::-1]

# %%
# simple demo on rewards [0,0,1,0,0,1]
get_cumulative_returns([0, 0, 1, 0, 0, 1], gamma=0.9)
# Out:
# array([1.40049, 1.5561 , 1.729  , 0.81   , 0.9    , 1.     ])

# %% [markdown]
# **Rollout**

# %%
def rollout(env, agent, max_pathlength=2500, n_timesteps=50000):
    """
    Generate rollouts for training.
    :param: env - environment in which we will make actions to generate rollouts.
    :param: act - the function that can return policy and action given observation.
    :param: max_pathlength - maximum size of one path that we generate.
    :param: n_timesteps - total sum of sizes of all pathes we generate.
    """
    paths = []

    total_timesteps = 0
    while total_timesteps < n_timesteps:
        obervations, actions, rewards, action_probs = [], [], [], []
        obervation = env.reset()
        for _ in range(max_pathlength):
            action, policy = agent.act(obervation)
            obervations.append(obervation)
            actions.append(action)
            action_probs.append(policy)
            obervation, reward, done, _ = env.step(action)
            rewards.append(reward)
            total_timesteps += 1
            if done or total_timesteps >= n_timesteps:
                path = {
                    "observations": np.array(obervations),
                    "policy": np.array(action_probs),
                    "actions": np.array(actions),
                    "rewards": np.array(rewards),
                    "cumulative_returns": get_cumulative_returns(rewards),
                }
                paths.append(path)
                break
    return paths

# %%
from pprint import pprint

paths = rollout(env, agent, max_pathlength=5, n_timesteps=100)
pprint(paths[-1])

assert (paths[0]['policy'].shape == (5, n_actions))
assert (paths[0]['cumulative_returns'].shape == (5,))
assert (paths[0]['rewards'].shape == (5,))
assert (paths[0]['observations'].shape == (5,) + observation_shape)
assert (paths[0]['actions'].shape == (5,))

print("It's ok")
# Out:
# {'actions': array([0, 1, 0, 1, 0]),
#  'cumulative_returns': array([-5., -4., -3., -2., -1.]),
#  'observations': array([[ 1.00000000e+00, -2.27854631e-04,  9.96505022e-01,
#          8.35331231e-02,  9.54755172e-02,  1.95453819e-02],
#        [ 9.99458551e-01,  3.29028293e-02,  9.98981893e-01,
#          4.51127701e-02,  2.27804989e-01, -3.92507911e-01],
#        [ 9.97342348e-01,  7.28573129e-02,  9.99525607e-01,
#         -3.07995211e-02,  1.61935538e-01, -3.47658038e-01],
#        [ 9.94243562e-01,  1.07143737e-01,  9.92659867e-01,
#         -1.20939381e-01,  1.72394678e-01, -5.35457432e-01],
#        [ 9.92264986e-01,  1.24137945e-01,  9.79829609e-01,
#         -1.99834675e-01, -6.81297155e-03, -2.48581931e-01]], dtype=float32),
#  'policy': array([[0.31759304, 0.33798254, 0.34442437],
#        [0.3195994 , 0.33265656, 0.34774405],
#        [0.31878096, 0.33332735, 0.34789172],
#        [0.31858364, 0.3307699 , 0.3506464 ],
#        [0.31754208, 0.3348433 , 0.3476146 ]], dtype=float32),
#  'rewards': array([-1., -1., -1., -1., -1.])}
# It's ok

# %% [markdown]
# ### Step 3: Auxiliary functions
#
# Now let's define the loss functions and something else for actual TRPO training.

# %% [markdown]
# The surrogate reward should be:
# $$J_{surr}= {1 \over N} \sum\limits_{i=1}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}A_{\theta_{old}(s_i, a_i)}$$
#
# For simplicity, in this assignment we are going to use cumulative rewards instead of advantage:
# $$J'_{surr}= {1 \over N} \sum\limits_{i=1}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}G_{\theta_{old}(s_i, a_i)}$$
#
# Since we want to maximize the reward, we are going to minimize the corresponding surrogate loss:
# $$ L_{surr} = - J'_{surr} $$

# %%
def get_loss(agent, observations, actions, cumulative_returns, old_probs):
    """
    Computes TRPO objective
    :param: observations - batch of observations [timesteps x state_shape]
    :param: actions - batch of actions [timesteps]
    :param: cumulative_returns - batch of cumulative returns [timesteps]
    :param: old_probs - batch of probabilities computed by old network [timesteps x num_actions]
    :returns: scalar value of the objective function
    """
    batch_size = observations.shape[0]
    probs_all = agent.get_probs(observations)

    probs_for_actions = probs_all[torch.arange(batch_size), actions]
    old_probs_for_actions = old_probs[torch.arange(batch_size), actions]

    # Compute surrogate loss, aka importance-sampled policy gradient
#     <YOUR CODE>
    loss = -torch.mean(cumulative_returns*(probs_for_actions/old_probs_for_actions))
#     print('loss: ', probs_for_actions*cumulative_returns/old_probs_for_actions)
#     print('loss shape:', (probs_for_actions*cumulative_returns/old_probs_for_actions).shape)
    
    
    assert loss.ndim == 0
    return loss

# %% [markdown]
# We can ascend these gradients as long as our $\pi_\theta(a|s)$ satisfies the constraint
# $$\mathbb{E}_{s,\pi_{\theta_{t}}} \Big[ \operatorname{KL} \left( \pi_{\theta_{t}} (s) \:\|\: \pi_{\theta_{t+1}} (s) \right) \Big] < \alpha$$
#
#
# where
#
# $$\operatorname{KL} \left( p \| q \right) = \mathbb{E}_p \log \left( \frac p q \right)$$

# %%
a = torch.tensor([[1,2,3,1,2], 
                  [8,2,2,1,2]])

b = torch.tensor([[10,7,3,4,5], 
                  [10,7,8,4,1]])

(a @ b.T).sum()/
# Out:
#   Cell In[22], line 7
#     (a @ b.T).sum()/
#                     ^
# SyntaxError: invalid syntax

# %%
def get_kl(agent, observations, actions, cumulative_returns, old_probs):
    """
    Computes KL-divergence between network policy and old policy
    :param: observations - batch of observations [timesteps x state_shape]
    :param: actions - batch of actions [timesteps]
    :param: cumulative_returns - batch of cumulative returns [timesteps] (we don't need it actually)
    :param: old_probs - batch of probabilities computed by old network [timesteps x num_actions]
    :returns: scalar value of the KL-divergence
    """
    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    # Compute Kullback-Leibler divergence (see formula above).
    # Note: you need to sum KL and entropy over all actions, not just the ones agent took.
    # You will also need to compute max KL over all timesteps.
    old_log_probs = torch.log(old_probs + 1e-10)

#     <YOUR CODE>
    
#     kl = torch.mean(old_probs * (old_log_probs - log_probs_all ))
    tmp = torch.sum(old_probs * (old_log_probs - log_probs_all), dim = -1)
    kl = torch.mean(tmp)
#     print(kl, my_way)
#     print('old_probs', old_probs.shape)
#     print('log_probs', (old_log_probs - log_probs_all).shape)
#     print('mult', (old_probs @ (old_log_probs - log_probs_all).T).shape)
    
    
#     print('kl:', (probs_all * (log_probs_all - old_log_probs)) )
#     print('kl shape:', (probs_all * (log_probs_all - old_log_probs)).shape )
    
    assert kl.ndim == 0
    assert (kl > -0.0001).all() and (kl < 10000).all()
    return kl

# %%
torch.tensor(1)
# Out:
# tensor(1)

# %%
def get_entropy(agent, observations):
    """
    Computes entropy of the network policy
    :param: observations - batch of observations
    :returns: scalar value of the entropy
    """

    observations = torch.tensor(observations, dtype=torch.float32)

    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    entropy = (-probs_all * log_probs_all).sum(dim=1).mean(dim=0)

    assert entropy.ndim == 0
    return entropy

# %% [markdown]
# **Linear search**
#
# TRPO in its core involves ascending surrogate policy gradient constrained by KL divergence.
#
# In order to enforce this constraint, we're gonna use linesearch. You can find out more about it [here](https://en.wikipedia.org/wiki/Linear_search)

# %%
def linesearch(f, x: torch.Tensor, fullstep: torch.Tensor, max_kl: float, max_backtracks: int = 10, backtrack_coef: float = 0.5):
    """
    Linesearch finds the best parameters of neural networks in the direction of fullstep contrainted by KL divergence.
    :param: f - function that returns loss, kl and arbitrary third component.
    :param: x - old parameters of neural network.
    :param: fullstep - direction in which we make search.
    :param: max_kl - constraint of KL divergence.
    :returns:
    """
    loss, _, = f(x)
    for stepfrac in backtrack_coef**np.arange(max_backtracks):
        xnew = x + stepfrac * fullstep
        new_loss, kl = f(xnew)
        if kl <= max_kl and new_loss < loss:
            x = xnew
            loss = new_loss
    return x

# %% [markdown]
# **Conjugate gradients**
#
# Since TRPO includes contrainted optimization, we will need to solve $A x = b$ using conjugate gradients.
#
# In general, CG is an algorithm that solves $A x = b$ where $A$ is positive-defined. $A$ is the Hessian matrix so $A$ is positive-defined. You can find out more about CG [here](https://en.wikipedia.org/wiki/Conjugate_gradient_method).

# %%
def conjugate_gradient(f_Ax, b, cg_iters=10, residual_tol=1e-10):
    """
    This method solves system of equation Ax=b using an iterative method called conjugate gradients
    :f_Ax: function that returns Ax
    :b: targets for Ax
    :cg_iters: how many iterations this method should do
    :residual_tol: epsilon for stability
    """
    p = b.clone()
    r = b.clone()
    x = torch.zeros_like(b)
    rdotr = torch.sum(r*r)
    for i in range(cg_iters):
        z = f_Ax(p)
        v = rdotr / (torch.sum(p*z) + 1e-8)
        x += v * p
        r -= v * z
        newrdotr = torch.sum(r*r)
        mu = newrdotr / (rdotr + 1e-8)
        p = r + mu * p
        rdotr = newrdotr
        if rdotr < residual_tol:
            break
    return x

# %%
# This code validates conjugate gradients
A = np.random.rand(8, 8)
A = A.T @ A


def f_Ax(x):
    return torch.ravel(torch.tensor(A, dtype=torch.float32) @ x.reshape(-1, 1))


b = np.random.rand(8)
w = (np.linalg.inv(A.T @ A) @ A.T @ b.reshape(-1, 1)).reshape(-1)

print(w)
print(conjugate_gradient(f_Ax, torch.tensor(b, dtype=torch.float32)).numpy())
# Out:
# [ 3.00894871  1.78790736 -4.52600467 -2.07609681  4.27658095 -0.98415712
#  -3.90340297  4.01964785]
# [ 3.0089457  1.7879124 -4.5259147 -2.0760849  4.276474  -0.9841284
#  -3.9034722  4.019711 ]

# %% [markdown]
# ### Step 4: training
# In this section we construct the whole update step function.

# %%
def update_step(agent, observations, actions, cumulative_returns, old_probs, max_kl):
    """
    This function does the TRPO update step
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cumulative_returns - batch of cumulative returns
    :param: old_probs - batch of probabilities computed by old network
    :param: max_kl - controls how big KL divergence may be between old and new policy every step.
    :returns: KL between new and old policies and the value of the loss function.
    """

    # Here we prepare the information
    observations = torch.tensor(observations, dtype=torch.float32)
    actions = torch.tensor(actions, dtype=torch.int64)
    cumulative_returns = torch.tensor(cumulative_returns, dtype=torch.float32)
    old_probs = torch.tensor(old_probs, dtype=torch.float32)

    # Here we compute gradient of the loss function
    loss = get_loss(agent, observations, actions, cumulative_returns, old_probs)
    grads = torch.autograd.grad(loss, agent.parameters())
    loss_grad = torch.cat([torch.ravel(grad.detach()) for grad in grads])

    def Fvp(v):
        # Here we compute Fx to do solve Fx = g using conjugate gradients
        # We actually do here a couple of tricks to compute it efficiently

        kl = get_kl(agent, observations, actions, cumulative_returns, old_probs)

        grads = torch.autograd.grad(kl, agent.parameters(), create_graph=True)
        flat_grad_kl = torch.cat([grad.reshape(-1) for grad in grads])

        kl_v = (flat_grad_kl * v).sum()
        grads = torch.autograd.grad(kl_v, agent.parameters())
        flat_grad_grad_kl = torch.cat([torch.ravel(grad) for grad in grads]).detach()

        return flat_grad_grad_kl + v * 0.1

    # Here we solve Fx = g system using conjugate gradients
    stepdir = conjugate_gradient(Fvp, -loss_grad, 10)

    # Here we compute the initial vector to do linear search
    shs = 0.5 * (stepdir * Fvp(stepdir)).sum(0, keepdim=True)

    lm = torch.sqrt(shs / max_kl)
    fullstep = stepdir / lm[0]

#     neggdotstepdir = (-loss_grad * stepdir).sum(0, keepdim=True)

    # Here we get the start point
    prev_params = get_flat_params_from(agent)

    def get_loss_kl(params):
        # Helper for linear search
        set_flat_params_to(agent, params)
        return [
            get_loss(agent, observations, actions, cumulative_returns, old_probs),
            get_kl(agent, observations, actions, cumulative_returns, old_probs),
        ]

    # Here we find our new parameters
    new_params = linesearch(get_loss_kl, prev_params, fullstep, max_kl)

    # And we set it to our network
    set_flat_params_to(agent, new_params)

    return get_loss_kl(new_params)

# %% [markdown]
# ### Step 5: Main TRPO loop
#
# Here we will train our network!

# %%
import time
from itertools import count

# TRPO hyperparameter; controls how big KL divergence may be between the old and the new policy at every step.
max_kl = 0.01
numeptotal = 0  # Number of episodes we have completed so far.

start_time = time.time()

for i in count(1):
    print("\n********** Iteration %i ************" % i)

    # Generating paths.
    print("Rollout")
    paths = rollout(env, agent)
    print("Made rollout")

    # Updating policy.
    observations = np.concatenate([path["observations"] for path in paths])
    actions = np.concatenate([path["actions"] for path in paths])
    returns = np.concatenate([path["cumulative_returns"] for path in paths])
    old_probs = np.concatenate([path["policy"] for path in paths])

    loss, kl = update_step(agent, observations, actions, returns, old_probs, max_kl)

    # Report current progress
    episode_rewards = np.array([path["rewards"].sum() for path in paths])

    stats = {}
    numeptotal += len(episode_rewards)
    stats["Total number of episodes"] = numeptotal
    stats["Average sum of rewards per episode"] = episode_rewards.mean()
    stats["Std of rewards per episode"] = episode_rewards.std()
    stats["Time elapsed"] = "%.2f mins" % ((time.time() - start_time)/60.)
    stats["KL between old and new distribution"] = kl.data.numpy()
    stats["Entropy"] = get_entropy(agent, observations).data.numpy()
    stats["Surrogate loss"] = loss.data.numpy()
    for k, v in stats.items():
        print(k + ": " + " " * (40 - len(k)) + str(v))
# Out:
# ********** Iteration 1 ************
# Rollout
# Made rollout
# Total number of episodes:                 101
# Average sum of rewards per episode:       -495.029702970297
# Std of rewards per episode:               41.38863273549579
# Time elapsed:                             0.37 mins
# KL between old and new distribution:      0.009995087
# Entropy:                                  1.0886468
# Surrogate loss:                           248.91904
#
# ********** Iteration 2 ************
# Rollout
# Made rollout
# Total number of episodes:                 202
# Average sum of rewards per episode:       -495.029702970297
# Std of rewards per episode:               41.59147271835984
# Time elapsed:                             0.75 mins
# KL between old and new distribution:      0.009987222
# Entropy:                                  1.0737723
# Surrogate loss:                           248.97832
#
# ********** Iteration 3 ************
# Rollout
# Made rollout
# Total number of episodes:                 302
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             1.11 mins
# KL between old and new distribution:      0.00998581
# Entropy:                                  1.075676
# Surrogate loss:                           249.9428
#
# ********** Iteration 4 ************
# Rollout
# Made rollout
# Total number of episodes:                 408
# Average sum of rewards per episode:       -471.4056603773585
# Std of rewards per episode:               57.491554474415246
# Time elapsed:                             1.47 mins
# KL between old and new distribution:      0.009989289
# Entropy:                                  1.0565116
# Surrogate loss:                           239.00153
#
# ********** Iteration 5 ************
# Rollout
# Made rollout
# Total number of episodes:                 535
# Average sum of rewards per episode:       -392.9212598425197
# Std of rewards per episode:               84.95710879862068
# Time elapsed:                             1.83 mins
# KL between old and new distribution:      0.009980993
# Entropy:                                  1.0374364
# Surrogate loss:                           205.00488
#
# ********** Iteration 6 ************
# Rollout
# Made rollout
# Total number of episodes:                 721
# Average sum of rewards per episode:       -267.8225806451613
# Std of rewards per episode:               63.066577943910396
# Time elapsed:                             2.19 mins
# KL between old and new distribution:      0.009988866
# Entropy:                                  0.9867058
# Surrogate loss:                           140.76184
#
# ********** Iteration 7 ************
# Rollout
# Made rollout
# Total number of episodes:                 946
# Average sum of rewards per episode:       -221.23111111111112
# Std of rewards per episode:               55.92622053393092
# Time elapsed:                             2.56 mins
# KL between old and new distribution:      0.009980626
# Entropy:                                  0.9500681
# Surrogate loss:                           117.0981
#
# ********** Iteration 8 ************
# Rollout
# Made rollout
# Total number of episodes:                 1195
# Average sum of rewards per episode:       -199.80722891566265
# Std of rewards per episode:               46.20048622755455
# Time elapsed:                             2.94 mins
# KL between old and new distribution:      0.0099834
# Entropy:                                  0.9181347
# Surrogate loss:                           104.70887
#
# ********** Iteration 9 ************
# Rollout
# Made rollout
# Total number of episodes:                 1500
# Average sum of rewards per episode:       -162.93770491803278
# Std of rewards per episode:               32.31463234488454
# Time elapsed:                             3.32 mins
# KL between old and new distribution:      0.009986782
# Entropy:                                  0.86405724
# Surrogate loss:                           84.30604
#
# ********** Iteration 10 ************
# Rollout
# Made rollout
# Total number of episodes:                 1854
# Average sum of rewards per episode:       -140.24576271186442
# Std of rewards per episode:               26.116190761642414
# Time elapsed:                             3.68 mins
# KL between old and new distribution:      0.009975975
# Entropy:                                  0.81605273
# Surrogate loss:                           72.27717
#
# ********** Iteration 11 ************
# Rollout
# Made rollout
# Total number of episodes:                 2221
# Average sum of rewards per episode:       -135.2425068119891
# Std of rewards per episode:               28.300615570554235
# Time elapsed:                             4.04 mins
# KL between old and new distribution:      0.009993081
# Entropy:                                  0.7922164
# Surrogate loss:                           70.29731
#
# ********** Iteration 12 ************
# Rollout
# Made rollout
# Total number of episodes:                 2588
# Average sum of rewards per episode:       -135.24523160762942
# Std of rewards per episode:               34.199364573160395
# Time elapsed:                             4.42 mins
# KL between old and new distribution:      0.009998829
# Entropy:                                  0.74898505
# Surrogate loss:                           71.55588
#
# ********** Iteration 13 ************
# Rollout
# Made rollout
# Total number of episodes:                 2988
# Average sum of rewards per episode:       -124.005
# Std of rewards per episode:               36.37505979376529
# Time elapsed:                             4.79 mins
# KL between old and new distribution:      0.009968408
# Entropy:                                  0.70993084
# Surrogate loss:                           66.86793
#
# ********** Iteration 14 ************
# Rollout
# Made rollout
# Total number of episodes:                 3400
# Average sum of rewards per episode:       -120.36893203883496
# Std of rewards per episode:               40.574991171511016
# Time elapsed:                             5.17 mins
# KL between old and new distribution:      0.009976478
# Entropy:                                  0.6861619
# Surrogate loss:                           66.64229
#
# ********** Iteration 15 ************
# Rollout
# Made rollout
# Total number of episodes:                 3846
# Average sum of rewards per episode:       -111.10986547085201
# Std of rewards per episode:               23.88010113099911
# Time elapsed:                             5.55 mins
# KL between old and new distribution:      0.009977047
# Entropy:                                  0.667189
# Surrogate loss:                           57.86887
#
# ********** Iteration 16 ************
# Rollout
# Made rollout
# Total number of episodes:                 4285
# Average sum of rewards per episode:       -112.89749430523918
# Std of rewards per episode:               29.439114700671738
# Time elapsed:                             5.92 mins
# KL between old and new distribution:      0.009995335
# Entropy:                                  0.66487235
# Surrogate loss:                           59.96098
#
# ********** Iteration 17 ************
# Rollout
# Made rollout
# Total number of episodes:                 4741
# Average sum of rewards per episode:       -108.65131578947368
# Std of rewards per episode:               27.8166600657963
# Time elapsed:                             6.29 mins
# KL between old and new distribution:      0.009990209
# Entropy:                                  0.64778495
# Surrogate loss:                           57.57688
#
# ********** Iteration 18 ************
# Rollout
# Made rollout
# Total number of episodes:                 5186
# Average sum of rewards per episode:       -111.36404494382022
# Std of rewards per episode:               33.63274971365486
# Time elapsed:                             6.66 mins
# KL between old and new distribution:      0.009978916
# Entropy:                                  0.65026015
# Surrogate loss:                           60.41999
#
# ********** Iteration 19 ************
# Rollout
# Made rollout
# Total number of episodes:                 5642
# Average sum of rewards per episode:       -108.65350877192982
# Std of rewards per episode:               31.294766335111394
# Time elapsed:                             7.03 mins
# KL between old and new distribution:      0.009991118
# Entropy:                                  0.6168555
# Surrogate loss:                           58.51533
#
# ********** Iteration 20 ************
# Rollout
# Made rollout
# Total number of episodes:                 6116
# Average sum of rewards per episode:       -104.4873417721519
# Std of rewards per episode:               24.89278376660843
# Time elapsed:                             7.39 mins
# KL between old and new distribution:      0.009983758
# Entropy:                                  0.5836973
# Surrogate loss:                           54.93889
#
# ********** Iteration 21 ************
# Rollout
# Made rollout
# Total number of episodes:                 6592
# Average sum of rewards per episode:       -104.04621848739495
# Std of rewards per episode:               31.71256753215789
# Time elapsed:                             7.76 mins
# KL between old and new distribution:      0.009995875
# Entropy:                                  0.5800961
# Surrogate loss:                           56.593296
#
# ********** Iteration 22 ************
# Rollout
# Made rollout
# Total number of episodes:                 7068
# Average sum of rewards per episode:       -104.0483193277311
# Std of rewards per episode:               38.76485588515956
# Time elapsed:                             8.14 mins
# KL between old and new distribution:      0.0099850865
# Entropy:                                  0.549188
# Surrogate loss:                           58.85894
#
# ********** Iteration 23 ************
# Rollout
# Made rollout
# Total number of episodes:                 7565
# Average sum of rewards per episode:       -99.6056338028169
# Std of rewards per episode:               30.825813747733633
# Time elapsed:                             8.51 mins
# KL between old and new distribution:      0.009981328
# Entropy:                                  0.5381217
# Surrogate loss:                           54.24966
#
# ********** Iteration 24 ************
# Rollout
# Made rollout
# Total number of episodes:                 8066
# Average sum of rewards per episode:       -98.80239520958084
# Std of rewards per episode:               27.414226136481997
# Time elapsed:                             8.88 mins
# KL between old and new distribution:      0.009999409
# Entropy:                                  0.5040059
# Surrogate loss:                           52.9425
#
# ********** Iteration 25 ************
# Rollout
# Made rollout
# Total number of episodes:                 8582
# Average sum of rewards per episode:       -95.90116279069767
# Std of rewards per episode:               25.128582482158567
# Time elapsed:                             9.26 mins
# KL between old and new distribution:      0.009984776
# Entropy:                                  0.4734085
# Surrogate loss:                           50.98574
#
# ********** Iteration 26 ************
# Rollout
# Made rollout
# Total number of episodes:                 9099
# Average sum of rewards per episode:       -95.7137330754352
# Std of rewards per episode:               29.771458054499785
# Time elapsed:                             9.63 mins
# KL between old and new distribution:      0.00998655
# Entropy:                                  0.43387356
# Surrogate loss:                           52.2131
#
# ********** Iteration 27 ************
# Rollout
# Made rollout
# Total number of episodes:                 9643
# Average sum of rewards per episode:       -90.91360294117646
# Std of rewards per episode:               21.556992661478784
# Time elapsed:                             10.01 mins
# KL between old and new distribution:      0.0088012405
# Entropy:                                  0.42016804
# Surrogate loss:                           47.86372
#
# ********** Iteration 28 ************
# Rollout
# Made rollout
# Total number of episodes:                 10181
# Average sum of rewards per episode:       -91.93866171003718
# Std of rewards per episode:               24.336663478937428
# Time elapsed:                             10.38 mins
# KL between old and new distribution:      0.0099826045
# Entropy:                                  0.4065029
# Surrogate loss:                           48.95811
#
# ********** Iteration 29 ************
# Rollout
# Made rollout
# Total number of episodes:                 10717
# Average sum of rewards per episode:       -92.28544776119404
# Std of rewards per episode:               29.69048438236081
# Time elapsed:                             10.75 mins
# KL between old and new distribution:      0.0099765975
# Entropy:                                  0.3963916
# Surrogate loss:                           50.61018
#
# ********** Iteration 30 ************
# Rollout
# Made rollout
# Total number of episodes:                 11256
# Average sum of rewards per episode:       -91.76808905380334
# Std of rewards per episode:               28.889720942329127
# Time elapsed:                             11.15 mins
# KL between old and new distribution:      0.009976139
# Entropy:                                  0.37040624
# Surrogate loss:                           50.18709
#
# ********** Iteration 31 ************
# Rollout
# Made rollout
# Total number of episodes:                 11799
# Average sum of rewards per episode:       -91.0828729281768
# Std of rewards per episode:               21.918536212157704
# Time elapsed:                             11.53 mins
# KL between old and new distribution:      0.009983596
# Entropy:                                  0.36303332
# Surrogate loss:                           47.94937
#
# ********** Iteration 32 ************
# Rollout
# Made rollout
# Total number of episodes:                 12326
# Average sum of rewards per episode:       -93.8785578747628
# Std of rewards per episode:               30.389009414201738
# Time elapsed:                             11.93 mins
# KL between old and new distribution:      0.009977361
# Entropy:                                  0.32363173
# Surrogate loss:                           51.57608
#
# ********** Iteration 33 ************
# Rollout
# Made rollout
# Total number of episodes:                 12881
# Average sum of rewards per episode:       -89.09189189189189
# Std of rewards per episode:               23.556499591351038
# Time elapsed:                             12.30 mins
# KL between old and new distribution:      0.009989809
# Entropy:                                  0.34043425
# Surrogate loss:                           47.38019
#
# ********** Iteration 34 ************
# Rollout
# Made rollout
# Total number of episodes:                 13438
# Average sum of rewards per episode:       -88.76840215439856
# Std of rewards per episode:               25.96915460318569
# Time elapsed:                             12.69 mins
# KL between old and new distribution:      0.009987218
# Entropy:                                  0.2946302
# Surrogate loss:                           47.95283
#
# ********** Iteration 35 ************
# Rollout
# Made rollout
# Total number of episodes:                 13995
# Average sum of rewards per episode:       -88.77019748653501
# Std of rewards per episode:               36.359233620090954
# Time elapsed:                             13.06 mins
# KL between old and new distribution:      0.009986884
# Entropy:                                  0.28461596
# Surrogate loss:                           51.517883
#
# ********** Iteration 36 ************
# Rollout
# Made rollout
# Total number of episodes:                 14548
# Average sum of rewards per episode:       -89.41772151898734
# Std of rewards per episode:               35.107185560667844
# Time elapsed:                             13.43 mins
# KL between old and new distribution:      0.0074448604
# Entropy:                                  0.2687378
# Surrogate loss:                           51.25667
#
# ********** Iteration 37 ************
# Rollout
# Made rollout
# Total number of episodes:                 15133
# Average sum of rewards per episode:       -84.47179487179487
# Std of rewards per episode:               18.969601621207655
# Time elapsed:                             13.81 mins
# KL between old and new distribution:      0.009984361
# Entropy:                                  0.27511886
# Surrogate loss:                           44.12652
#
# ********** Iteration 38 ************
# Rollout
# Made rollout
# Total number of episodes:                 15698
# Average sum of rewards per episode:       -87.49734513274336
# Std of rewards per episode:               17.679008402182042
# Time elapsed:                             14.20 mins
# KL between old and new distribution:      0.009986513
# Entropy:                                  0.2933879
# Surrogate loss:                           45.31897
#
# ********** Iteration 39 ************
# Rollout
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 15
#      13 # Generating paths.
#      14 print("Rollout")
# ---> 15 paths = rollout(env, agent)
#      16 print("Made rollout")
#      18 # Updating policy.
#
# Cell In[19], line 16, in rollout(env, agent, max_pathlength, n_timesteps)
#      14 obervation = env.reset()
#      15 for _ in range(max_pathlength):
# ---> 16     action, policy = agent.act(obervation)
#      17     obervations.append(obervation)
#      18     actions.append(action)
#
# Cell In[14], line 67, in TRPOAgent.act(self, obs, sample)
#      59 '''
#      60 Samples action from policy distribution (sample = True) or takes most likely action (sample = False)
#      61 :param: obs - single observation vector
#      62 :param sample: if True, samples from \pi, otherwise takes most likely action
#      63 :returns: action (single integer) and probabilities for all actions
#      64 '''
#      66 with torch.no_grad():
# ---> 67     probs = self.get_probs(torch.tensor(obs[np.newaxis], dtype=torch.float32)).numpy()
#      69 if sample:
#      70     action = int(np.random.choice(n_actions, p=probs[0]))
#
# Cell In[14], line 56, in TRPOAgent.get_probs(self, states)
#      52 def get_probs(self, states: torch.Tensor):
#      53     '''
#      54     Probs for interaction
#      55     '''
# ---> 56     return torch.exp(self.forward(states))
#
# Cell In[14], line 30, in TRPOAgent.forward(self, states)
#      24         """
#      25         takes agent's observation, returns log-probabilities
#      26         :param state_t: a batch of states, shape = [batch_size, state_shape]
#      27         """
#      29         # Use your network to compute log_probs for the given states.
# ---> 30         model = nn.Sequential(
#      31             self.dense_in,
#      32             self.relu,
#      33
#      34             self.dense_hid,
#      35             self.relu,
#      36
#      37             self.dense_out,
#      38             self.log_softmax
#      39         )
#      40         log_probs = model(states)
#      41 #         counts = logits.exp()
#      42 #         probs = logits / logits.sum(-1, keepdims=True)
#
# File ~/.local/share/virtualenvs/Practical_RL_course-acchW1SA/lib/python3.10/site-packages/torch/nn/modules/container.py:84, in Sequential.__init__(self, *args)
#      80 @overload
#      81 def __init__(self, arg: 'OrderedDict[str, Module]') -> None:
#      82     ...
# ---> 84 def __init__(self, *args):
#      85     super(Sequential, self).__init__()
#      86     if len(args) == 1 and isinstance(args[0], OrderedDict):
#
# KeyboardInterrupt:

# %% [markdown]
# # Homework option I: better sampling (10+pts)
#
# In this section, you're invited to implement a better rollout strategy called _vine_.
#
# ![img](https://s17.postimg.cc/i90chxgvj/vine.png)
#
# In most gym environments, you can actually backtrack by using states. You can find a wrapper that saves/loads states in [the MCTS seminar](https://github.com/yandexdataschool/Practical_RL/blob/master/week10_planning/seminar_MCTS.ipynb).
#
# You can read more about TRPO in the [original paper](https://arxiv.org/abs/1502.05477) in section 5.2.
#
# The goal here is to implement such rollout policy (we recommend using tree data structure like in the seminar above).
# Then you can assign cumulative rewards similar to `get_cumulative_rewards`, but for a tree.
#
# __bonus task__ - parallelize samples using multiple cores

# %% [markdown]
# # Homework option II (10+pts)
#
# Let's use TRPO to train evil robots! (pick any of two)
# * [MuJoCo robots](https://gym.openai.com/envs#mujoco)
# * [Box2d robot](https://gym.openai.com/envs/BipedalWalker-v2)
#
# The catch here is that those environments have continuous action spaces.
#
# Luckily, TRPO is a policy gradient method, so it's gonna work for any parametric $\pi_\theta(a|s)$. We recommend starting with gaussian policy:
#
# $$\pi_\theta(a|s) = N(\mu_\theta(s),\sigma^2_\theta(s)) = {1 \over \sqrt { 2 \pi {\sigma^2}_\theta(s) } } e^{ (a -
# \mu_\theta(s))^2 \over 2 {\sigma^2}_\theta(s) } $$
#
# In the $\sqrt { 2 \pi {\sigma^2}_\theta(s) }$ clause, $\pi$ means ~3.1415926, not agent's policy.
#
# This essentially means that you will need two output layers:
# * $\mu_\theta(s)$, a dense layer with linear activation
# * ${\sigma^2}_\theta(s)$, a dense layer with activation tf.exp (to make it positive; like rho from bandits)
#
# For multidimensional actions, you can use a fully factorized gaussian (basically a vector of gaussians).
#
# __Bonus task__: compare the performance of the continuous action space method to action space discretization.
